# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB

# %%
dataset = pd.read_csv ("placement_1.csv")
dataset.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.kdeplot (data = dataset["cgpa"])
plt.show()

# %%
sns.scatterplot (x = "cgpa", y = "resume_score", hue = "placed", data = dataset)
plt.show()

# %%
x = dataset.iloc[:, :-1]
y = dataset["placed"]

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, test_size = 0.2, random_state = 42)

# %% [markdown]
# ## Gausian Naive Bayes

# %%
gnb = GaussianNB()
gnb.fit (x_train, y_train)
# Out:
# GaussianNB()

# %%
gnb.score (x_test, y_test)*100, gnb.score (x_train, y_train)*100
# Out:
# (100.0, 97.5)

# %%
gnb.predict([[6.17, 5.17]])
# Out:
# c:\Users\Aamir Neyazi\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
plot_decision_regions (x.to_numpy(), y.to_numpy(), clf = gnb)
# Out:
# c:\Users\Aamir Neyazi\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# <Axes: >

# %% [markdown]
# ## Multinomial Naive Bayes

# %%
mnb = MultinomialNB()
mnb.fit (x_train, y_train)
# Out:
# MultinomialNB()

# %%
mnb.score (x_test, y_test)*100, mnb.score (x_train, y_train)*100
# Out:
# (75.0, 73.75)

# %%
plot_decision_regions (x.to_numpy(), y.to_numpy(), clf = mnb)
# Out:
# c:\Users\Aamir Neyazi\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(
# <Axes: >

# %% [markdown]
# ## Bernouli Naive Bayes

# %%
bnb = BernoulliNB()
bnb.fit (x_train, y_train)
# Out:
# BernoulliNB()

# %%
bnb.score (x_test, y_test)*100, bnb.score (x_train, y_train)*100
# Out:
# (50.0, 50.0)

# %%
plot_decision_regions (x.to_numpy(), y.to_numpy(), clf = bnb)
# Out:
# c:\Users\Aamir Neyazi\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but BernoulliNB was fitted with feature names
#   warnings.warn(
# <Axes: >
